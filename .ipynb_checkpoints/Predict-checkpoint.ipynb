# %%
import re
import json
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import numpy as np
import os
from pickle import dump, load
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 文件路径列表
file_paths = [
    'D:\\学习\\Postgra\\Text Technologies for Data Science\\Project\\Query-Processing\\OneDrive_1_2024-2-16\\combined123\\combined_part_1.jsonl',
    'D:\\学习\\Postgra\\Text Technologies for Data Science\\Project\\Query-Processing\\OneDrive_1_2024-2-16\\combined123\\combined_part_2.jsonl',
    'D:\\学习\\Postgra\\Text Technologies for Data Science\\Project\\Query-Processing\\OneDrive_1_2024-2-16\\combined123\\combined_part_3.jsonl',
    'D:\\学习\\Postgra\\Text Technologies for Data Science\\Project\\Query-Processing\\OneDrive_1_2024-2-16\\combined123\\combined_part_4.jsonl',
    'D:\\学习\\Postgra\\Text Technologies for Data Science\\Project\\Query-Processing\\OneDrive_1_2024-2-16\\combined123\\combined_part_5.jsonl'
]

# 打开一个新文件用于写入所有标题
with open('all_titles.txt', 'w', encoding='utf-8') as out_file:
    # 遍历文件路径
    for file_path in file_paths:
        # 打开文件并逐行读取
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                # 将每行的内容从JSON字符串转换为字典
                article = json.loads(line)
                # 替换掉标题中的换行符'\n'，然后写入到输出文件中
                title = article['title'].replace('\n', ' ')
                out_file.write(title + '\n')

# %%
def preprocess_text(text):
    """
    预处理文本：转换为小写并去除非字母数字字符
    """
    # 转换为小写
    text = text.lower()
    # 使用正则表达式去除非字母数字字符
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return text

# 输入文件路径
input_file_path = 'all_titles.txt'
# 输出文件路径
output_file_path = 'preprocessed_titles.txt'

# 读取输入文件，预处理每一行，然后写入到输出文件
with open(input_file_path, 'r', encoding='utf-8') as in_file, \
     open(output_file_path, 'w', encoding='utf-8') as out_file:
    for line in in_file:
        preprocessed_line = preprocess_text(line)
        out_file.write(preprocessed_line + '\n')

# %%
file_path = 'preprocessed_titles.txt'

titles = []
with open(file_path, 'r', encoding='utf-8') as file:
    for i, line in enumerate(file):
        if i < 5000:  # 仅读取前5000行
            title = line.strip().lower()
            titles.append(title)
        else:
            break  # 当读取到5000行时，退出循环

# %%
titles
# Out:
# ['unbiased intestinal single cell transcriptomics reveals previously uncharacterized enteric nervous system populations in larval zebrafish',
#  '',
#  'effect of ulv malathion on automotive paint finishes',
#  '',
#  'a new criteria for determining the best decomposition level and filter for waveletbased datadriven forecasting frameworks validating using three case studies on the camels dataset',
#  '',
#  'regulation of ntype calcium channels by nociceptin receptors and its possible role in neurological disorders',
#  '',
#  'association of serum lipids and abnormal lipid score with cancer risk a populationbased prospective study',
#  '',
#  'exploring the singlecell rnaseq analysis landscape with the scrnatools database',
#  '',
#  'griseolic acid an inhibitor of cyclic adenosine 35monophosphate phosphodiesterase i taxonomy isolation and characterization',
#  '',
#  'logic programming and logarithmic space',
#  '',
#  'the right formula',
#  '',
#  'pseudo transient continuation and time marching methods for mongeampere   type equations',
#  '',
#  'phase transitions in softly broken n2 sqcd at nonzero theta angle',
#  '',
#  'the',
#  '',
#  'the nature buffer the missing link in climate change and mental health research',
#  '',
#  'a crosscultural research experience developing an appropriate methodology that respectfully incorporates both indigenous and nonindigenous knowledge systems',
#  '',
#  'generative reproduction and genetic processes in nature',
#  '',
#  'estimating channel parameters from the syndrome of a linear code',
#  '',
#  'disease activity and subcutaneous nodules are associated to severe periodontitis in patients with rheumatoid arthritis',
#  '',
#  'considerations in the outpatient and office administration of cisplatin',
#  '',
#  'effect of a potent synthetic opioid pentapeptide in some antinociceptive and behavioural tests in mice and rats proceedings',
#  '',
#  'incidence and risk factor of allergic contact dermatitis to 2octyl cyanoacrylate and nbutyl cyanoacrylate topical skin adhesives',
#  '',
#  'on the approximate compressibility of connected vertex cover',
#  '',
#  'mehrdimensionale betrachtungen bei tinnitus',
#  '',
#  'reduction in thermal conductivity and electrical resistivity of indium and tellurium codoped bismuth selenide thermoelectric system',
#  '',
#  'mechanism of the sliding betaclamp of dna polymerase iii holoenzyme',
#  '',
#  'kinetics of formation of twinned structures under l10 type orderings in   alloys',
#  '',
#  'slave spin cluster mean field theory away from halffilling application   to the hubbard and the extended hubbard model',
#  '',
#  'man and insect past present future',
#  '',
#  'doc will my relative wake up and be normal',
#  '',
#  'on the nonuniqueness of the quasistatic magnetic forward problem and   its impact on source current reconstruction',
#  '',
#  'neutral epigenetic inheritance being prepared for future generations',
#  '',
#  'posterior porcelain bonded inlays',
#  '',
#  'effects of kainic acid analogues on the high affinity uptake of d3h aspartate into rat cerebellar homogenates',
#  '',
#  'syringe exchange schemes',
#  '',
#  'causality of singular linear discrete time systems',
#  '',
#  'the escherichia coli fdv gene probably encodes muts and is located at minute 588 adjacent to the hychyp gene cluster',
#  '',
#  'importing law reform  vietnamese company law as a case study',
#  '',
#  'a rectosigmoid lesion due to transanal aspiration apropos of a case',
#  '',
#  'no title found',
#  '',
#  'the correlation functions of the d4a6 conformal model',
#  '',
#  'asymptotic bounds on the equilateral dimension of hypercubes',
#  '',
#  'cardiomyopathy in leukemia with reference to rubidomycin cardiotoxicity',
#  '',
#  'xray and euv spectroscopy of the boundary layer emission of nonmagnetic   cataclysmic variables',
#  '',
#  'mrmrssa a hybrid approach for optimal feature selection',
#  '',
#  'onset of quiescence following p53 mediated downregulation of h2ax in normal cells',
#  '',
#  'intraneuronal chloride accumulation via nkcc1 is not essential for hippocampal network development in vivo',
#  '',
#  'influence of prostaglandin e1 on cerebral mechanisms involved in the control of fluid balance',
#  '',
#  'the role and future of the pathologist in cytology',
#  '',
#  'effects of a hyperbaric environment on respiratory and monoamine oxidase activities',
#  '',
#  'computational and experimental hunt for expansion prone tandem cng repeats in human genomes',
#  '',
#  'tizanidine vs baclofen in the treatment of spasticity in patients with multiple sclerosis',
#  '',
#  'prevention and control of animal disease outbreaks in switzerland 17981803',
#  '',
#  'polyamines eliminate an extreme size bias against transformation of large yeast artificial chromosome dna',
#  '',
#  'on the wellposedness of weakly hyperbolic equations with time dependent   coefficients',
#  '',
#  'application of raman spectroscopy for analysis of carbon nanotube distribution in living cells',
#  '',
#  'introducing breastfeeding into modern health services',
#  '',
#  'the effects of deep pressure touch on anxiety',
#  '',
#  'non functional malignant nesidioblastoma about one case authors transl',
#  '',
#  'clotting factors in burn sepsis',
#  '',
#  'investigations on microbial sulfur respiration isolation purification and characterization of cellular components from spirillum 5175',
#  '',
#  'sphincterpreserving interventions in rectal tumors transabdominal rectum resection',
#  '',
#  'preventive effects of cyclosporin on diabetes in nod mice',
#  '',
#  'gray scale ultrasound and the genitourinary tract a review of clinical applications',
#  '',
#  'estimates of critical quantities from an expansion in mass ising model   on the simple cubic lattice',
#  '',
#  'selfsimilar fragmentations derived from the stable tree ii splitting   at nodes',
#  '',
#  'high level gentamicin resistance in enterococcal and streptococcal isolates from blood culture',
#  '',
#  'study on the forming and sensing properties of lasersintered tpucnt composites for plantar pressure sensors',
#  '',
#  'in this issue',
#  '',
#  'hydrothermal synthesis of hydrosilicate nanoscrolls mg1  xcox3si2o5oh4 in a na2so3 solution',
#  '',
#  'phosphorus31 nuclear magnetic resonance studies of active proton translocation in chromaffin granules',
#  '',
#  'enos snitrosylates actin on cys374 and regulates pkc at the immune synapse by impairing actin binding to profilin1',
#  '',
#  'subspace detours meet gromovwasserstein',
#  '',
#  '7th meeting 2nd frenchitalian meeting on neuroanesthesiaresuscitation neuroendocrinology rouen 1819 october 1985 1',
#  '',
#  'significance of the gravitation factor in the final stage of a space flight',
#  '',
#  'splenic abscess a new case',
#  '',
#  'frames of translates for model sets',
#  '',
#  'malignant melanoma data from a gdansk clinic',
#  '',
#  'existence of propagators for time dependent coulomblike potentials',
#  '',
#  'field trial of talc direct recording scale',
#  '',
#  'obituary sumner l koch 18881976',
#  '',
#  'the number of partial steiner systems and dpartitions',
#  '',
#  'glucose6phosphate dehydrogenase deficiency and lung cancer a hospital based casecontrol study',
#  '',
#  'toxicological studies of shale oils some of their components and commercial products',
#  '',
#  'personal reflections on the role of sexuality in the etiology and treatment of the neuroses panel report',
#  '',
#  'the association of payer with utilization of cardiac procedures in massachusetts',
#  '',
#  'crossover axillary bypass treatment of subclavian or innominate artery obstructive lesions',
#  '',
#  'history on filmfilm on history',
#  '',
#  'a quark meson coupling model with density and temperature dependent   quark masses',
#  '',
#  'the view box',
#  '',
#  'calling a spade a spade mathematics in the new pattern of division of   labour',
#  '',
#  'contributors to this issue',
#  '',
#  'no axillary surgical treatment for lymph nodenegative patients after ultrasonography nautilus protocol of a prospective randomized clinical trial',
#  '',
#  'future euuk research and higher education cooperation at risk what is at stake',
#  '',
#  'clinical significance of osaka prognostic score based on nutritional and inflammatory status in patients with esophageal squamous cell carcinoma',
#  '',
#  'effects of methylphenidate ritalin on selective attention in hyperactive children',
#  '',
#  'inequalities in demand and access to early childhood education in india',
#  '',
#  'vsig4 peritoneal macrophages induce apoptosis of doublepositive thymocyte via the secretion of tnf in a clpinduced sepsis model resulting in thymic atrophy',
#  '',
#  'quicker dissemination of information',
#  '',
#  'diagnostik und therapie der syphilis',
#  '',
#  'conical averagedness and convergence analysis of fixed point algorithms',
#  '',
#  'quadrupole association and dissociation of hydrogen in the early   universe',
#  '',
#  'intrapericardial teratoma',
#  '',
#  'clinical implications of pachyvessels in polypoidal choroidal vasculopathy',
#  '',
#  'the effect of rauscher murine leukemia virus infection on the hemopoietic system of balbc mice cell proliferation and cell loss',
#  '',
#  'linear morphea involving the underlying muscle',
#  '',
#  'looking into pandoras box the content of scihub and its usage',
#  '',
#  'insulinmediated endothelin signaling is antiviral during west nile virus infection',
#  '',
#  'estimating the timing of stillbirths in countries worldwide using a   bayesian hierarchical penalized splines regression model',
#  '',
#  'threedimensional lattice sunc gauge theories with multiflavor   scalar fields in the adjoint representation',
#  '',
#  'tryptophan auxotrophic mutants in aspergillus niger inactivation of the trpc gene by cotransformation mutagenesis',
#  '',
#  'effects of ce la cu and fe promoters on nimgal2o4 catalysts in steam reforming of propane',
#  '',
#  'enumeration of distinct support vectors for interactive decision making',
#  '',
#  'the sketch of a polymorphic symphony',
#  '',
#  'decision impact and feasibility of different ascorecommended biomarkers in early breast cancer prospective comparison of molecular marker endopredict and protein marker upapai1',
#  '',
#  'genomic and subgenomic rnas of rabbit hemorrhagic disease virus are both proteinlinked and packaged into particles',
#  '',
#  'embryonal rhabdomyosarcoma associated with maternal ingestion of stilboestrol',
#  '',
#  'construction and box dimension of recurrent fractal interpolation   surfaces',
#  '',
#  'planckscale lorentzsymmetry test theories',
#  '',
#  'antibacterials',
#  '',
#  'universality classes of topological phase transitions with higherorder   band crossing',
#  '',
#  'improvement of microstructure hardness and mechanical properties of cobaltbased amorphous coating via laser cladding',
#  '',
#  'preliminary chacterization of a small intestinal binding component for retinol and fatty acids in the rat',
#  '',
#  'human ige mrna expression by peripheral blood lymphocytes stimulated with interleukin 4 and pokeweed mitogen',
#  '',
#  'institutional resource requirements and cost per student for contemporary pharmaceutical education',
#  '',
#  'a study of external galaxies detected by cobedirbe',
#  '',
#  'extracellular atp induces the release of calcium from intracellular stores without the activation of protein kinase c in swiss 3t6 mouse fibroblasts',
#  '',
#  'improving the quality of life during chemotherapy for advanced breast cancer a comparison of intermittent and continuous treatment strategies',
#  '',
#  'on the determination of lognormal flux distributions for astrophysical   systems',
#  '',
#  'retraction opposing signaling pathways regulate morphology in response to temperature in the fungal pathogen',
#  '',
#  'on the connection between adversarial robustness and saliency map   interpretability',
#  '',
#  'tv teaches home nursing',
#  '',
#  'language endangerment and resilience linguistics case studies of gong and lisu',
#  '',
#  'particleproduction mechanism in relativistic heavyion collisions',
#  '',
#  'quarklepton complementarity model based predictions for   theta23pmns with neutrino mass hierarchy',
#  '',
#  'quality assurance updateintroducing the system',
#  '',
#  'countryscale exploratory analysis of call detail records through the   lens of data grid models',
#  '',
#  'input price discrimination and upstream rd investments',
#  '',
#  'capsule routing for sound event detection',
#  '',
#  'room temperature multiferroicity in a transition metal dichalcogenide',
#  '',
#  'central nervous system site of action for the hypotensive effect of clonidine in the cat',
#  '',
#  'the photographer in the operating room',
#  '',
#  'prenatal exposure to environmental prooxidants induces mitochondriamediated epigenetic changes a crosssectional pilot study',
#  '',
#  'the microwave resonance therapy of reflux esophagitis',
#  '',
#  'the role of epsteinbarr virus ebv in various human disorders',
#  '',
#  'cutting through the clutter how the brain learns to see',
#  '',
#  'use of mesiodistal clasps in design of removable partial dentures',
#  '',
#  'chromopolarizability of charmonium and pipi final state interaction   revisited',
#  '',
#  'azd1222elasomerantozinameran',
#  '',
#  'ionic fluids charge and density correlations near gasliquid   criticality',
#  '',
#  'macroscopic manifestations of traffic waves in microscopic models',
#  '',
#  'lacosamide',
#  '',
#  'ball on a beam stabilization under saturated input control with large   basin of attraction',
#  '',
#  'informationen der samm',
#  '',
#  'densityfunctional theory for 1d harmonically trapped bosefermi mixture',
#  '',
#  'fournucleon scattering with a correlated gaussian basis method',
#  '',
#  'transfusion acquired serratia liquefaciens septicaemia',
#  '',
#  'contact laser for transscleral photocoagulation',
#  '',
#  'enhanced sensitivity of pituitary cells to corticosteroids in neonatal rats',
#  '',
#  'supplementary uses of the suction device for resident training in ear surgery',
#  '',
#  'the drosophila transcript encoded by the betaamyloid protein precursorlike gene is restricted to the nervous system',
#  '',
#  'on the number of ground states of the edwardsanderson spin glass model',
#  '',
#  'integration of mammalian microbial and drosophila procedures for evaluating chemical mutagens',
#  '',
#  'shining a light on the grey zones of gender construction breast surgery in france and italy',
#  '',
#  'ureteropelvic junction obstruction in childhood',
#  '',
#  'a sublinear bound on the cop throttling number of a graph',
#  '',
#  'acupuncture for the treatment of asthma',
#  '',
#  'unsupervised software defect prediction using median absolute deviation threshold based spectral classifier on signed laplacian matrix',
#  '',
#  'diminished gastrointestinal potentiation of insulin secretion in human pregnancy',
#  '',
#  'the consensus 5 splice site motif inhibits mrna nuclear export',
#  '',
#  'how adapting to research setbacks can pave the way to greater outcomes',
#  '',
#  'chitosancaffeine formulation as an ecological preservative in wood protection',
#  '',
#  'nebulized sodium cromoglycate in young asthmatic children doubleblind trial',
#  '',
#  'glucosyl transferase activity of bovine galactosyl transferase',
#  '',
#  'synthesis and structure of nickelii complex with methylsubstituted n2o2 tetradentate shiff base',
#  '',
#  'results of the first mapping of soiltransmitted helminths in benin evidence of countrywide hookworm predominance',
#  '',
#  'the new lithotripsy index predicts success of shock wave lithotripsy',
#  '',
#  'crossover in dynamics in the kobandersen binary mixture glassforming   liquid',
#  '',
#  'densification microstructure and tribomechanical performance of spsprocessed 27rsialon polytypereinforced aln a comparison between continuous and pulsed direct current mode',
#  '',
#  'decreased kinase activity of insulin receptors from adipocytes of noninsulindependent diabetic subjects',
#  '',
#  'charged antiparticle to particle ratios near midrapidity in pp   collisions at sqrtsnn200 gev',
#  '',
#  'exercise induced bronchospasm and associated factors in primary school children a crosssectional study',
#  '',
#  'iapertra film  visuality  culturei mapping the visual through a contemporary film studies and visual culture journal',
#  '',
#  'immunoglobulin a antibody against hepatitis b core antigen in the acute and persistent infection with hepatitis b virus',
#  '',
#  'minimum sharedpower edge cut',
#  '',
#  'embedding laser generated nanocrystals in bivo4 photoanode for efficient photoelectrochemical water splitting',
#  '',
#  'serratia species isolated from bovine intramammary infections',
#  '',
#  'anticonformism in the threshold model of collective behavior',
#  '',
#  'mddl a framework for reinforcement learningbased position allocation   in multichannel feed',
#  '',
#  'serge sergeevich iudin',
#  '',
#  'uptodate entomological aspects in the previously endemic areas of malaria in the danube plain and dobrudja',
#  '',
#  'thermoconforming rays of the starnosed mole',
#  '',
#  'effect of hydrocortisone on membrane potentials and synthesis of rna fractions in liver cells',
#  '',
#  'a fuzzy rough set approach to hierarchical feature selection based on hausdorff distance',
#  '',
#  'on the relation between lifting obstructions and ordinary obstructions',
#  '',
#  'carbon caution',
#  '',
#  'geniposide augments apoptosis in fibroblastlike synoviocytes by restoring hypoxiaenhanced jnkbnip3mediated autophagy',
#  '',
#  'impact of histone deacetylase inhibition and arimoclomol on heat shock protein expression and disease biomarkers in primary culture models of familial als',
#  '',
#  'turners anthropology of media and its legacies',
#  '',
#  'group trisections and smooth 4manifolds',
#  '',
#  'distinct and atypical intrinsic and extrinsic cell death pathways between photoreceptor cell types upon specific ablation of',
#  '',
#  'evidence of rapid evolution of an invasive poaceae in response to salinity',
#  '',
#  'interest in preexposure prophylaxis prep for hiv is limited among women in a general obstetrics  gynecology setting',
#  '',
#  'supply chain management practices and agribusiness firms performance mediating role of supply chain integration',
#  '',
#  'energy and exergy 2e analysis of a jet pumpassisted ejector cooling system',
#  '',
#  'linear accelerator calibration monitor with a memory',
#  '',
#  'reproducing gender refugee advocacy and sexual and genderbased violence in refugee narratives',
#  '',
#  'a genomeengineered bioartificial implant for autoregulated anticytokine drug delivery',
#  '',
#  'radio sources from a 31 ghz sky survey with the sunyaevzeldovich array',
#  '',
#  'tachypleus lysate test for endotoxin in patients with gram negative bacterial infections',
#  '',
#  'combinatorial theory of the semiclassical evaluation of transport   moments i equivalence with the random matrix approach',
#  '',
#  'vulnerability ageism and health is it helpful to label older adults as a vulnerable group in health care',
#  '',
#  'symposium planning of health care by all when we have some misgivings about our health',
#  '',
#  'determinations of flavor ratios and flavor transitions of astrophysical   neutrinos',
#  '',
#  'new constructions for covering designs',
#  '',
#  'soliton molecules robust clusters of light bullets',
#  '',
#  'unexpected stress corrosion cracking improvement achieved by recrystallized layer in alznmg alloy',
#  '',
#  'a study on harvesting of pkl electricity',
#  '',
#  'identification of the ckit ligand end of the road for understanding aplastic anemia in steel mutant mice',
#  '',
#  'calibrating the dynamic huff model for business analysis using location   big data',
#  '',
#  'appendicitis in the newborns',
#  '',
#  'ultrastructure of the heart of the copepod anomalocera ornata sutcliffe',
#  '',
#  'a farey tale for n4 dyons',
#  '',
#  'on variants of the matroid secretary problem',
#  '',
#  'highquality thermal gibbs sampling with quantum annealing hardware',
#  '',
#  'optimization of neuroprosthetic vision via endtoend deep reinforcement learning',
#  '',
#  'the international cooperation between developed capitalist countries in the field of medical science and public health',
#  '',
#  'generalized mean residual life models for casecohort and nested casecontrol studies',
#  '',
#  'implementing fully relativistic hydrodynamics in three dimensions',
#  '',
#  'a responsible internet to increase trust in the digital world',
#  '',
#  'duration of sleep and wakefulness in roman strain rats',
#  '',
#  'the dragonfly galaxy iii jetbrightening of a highredshift radio   source caught in a violent merger of disk galaxies',
#  '',
#  'wideopen accelerating public data release by automating detection of overdue datasets',
#  '',
#  'identification of the targets of hematoporphyrin derivative in lung adenocarcinoma using integrated network analysis',
#  '',
#  'does a particle swept by a turbulent liquid diffuse',
#  '',
#  'small intestinal mucosal histology in the syndrome of persistent diarrhoea and malnutrition a review',
#  '',
#  'adam17 silencing in mouse colon carcinoma cells the effect on tumoricidal cytokines and angiogenesis',
#  '',
#  'free radical production and dna cleavage by copper chelating peptideanthraquinones',
#  '',
#  'antibacterials',
#  '',
#  'analyticity and supershift with regular sampling',
#  '',
#  'functional and subcellular changes in the isolated rat heart perfused with oxidized isoproterenol',
#  '',
#  'therapeutischer durchbruch in sicht',
#  '',
#  'graph convolutional networks with eigenpooling',
#  '',
#  'program committee',
#  '',
#  'the ethics of interrelationships in small medical collectives',
#  '',
#  'structure of the yeast ceramide synthase',
#  '',
#  'sources toxicity potential and human health risk assessment of heavy metalsladen soil and dust of urban and suburban areas as affected by industrial and mining activities',
#  '',
#  'the influence of n7 platination and methylation on the stability of deoxyguanosine and deoxyguanylyl35deoxyguanosine',
#  '',
#  'the effects of changing the phase and duration of sleep',
#  '',
#  'neuropeptide y suppresses sympathetic activity to interscapular brown adipose tissue in rats',
#  '',
#  'a revision of the genus gouania rhamnaceae in the philippines and sundaland',
#  '',
#  'cloning and expression of an inducible lymphoidspecific protein tyrosine phosphatase heptpase',
#  '',
#  'recurrent hemolytic anemia secondary to acessory spleens',
#  '',
#  'continuing education in the public health ministry of cuba',
#  '',
#  'genomic profiling of ngsbased ctdna from chinese nonsmall cell lung cancer patients',
#  '',
#  'fluctuation analysis for a class of nonlinear systems with fast periodic   sampling and small statedependent white noise',
#  '',
#  'strain differentiation of neisseria gonorrhoeae by reverse passive hemagglutination',
#  '',
#  'can one detect new physics in i0 andor i2 contributions to the decays   b  pi pi',
#  '',
#  'structural and functional mri data differentially predict chronological age and behavioral memory performance',
#  '',
#  'ab initio oscillator strengths for transitions between j1 odd and j12   even excited states of ne i',
#  '',
#  're depomedrol and facet joint injections',
#  '',
#  'healthcare worker perceived barriers and facilitators to implementing a tuberculosis preventive therapy program in rural south africa a content analysis using the consolidated framework for implementation research',
#  '',
#  'the infrared emission of ultraviolet selected galaxies from z  0 to z1',
#  '',
#  'diclofenac release from alginatecarboxymethyl cellulose mono and bilayer films for wound dressing applications',
#  '',
#  'rapid method for construction of yeast artificial chromosome human dna libraries involving the trapping of cells in agarose films',
#  '',
#  'primordial regular black holes thermodynamics and dark matter',
#  '',
#  'modalnoise in singlemode fibers a cautionary note for high   precision radial velocity instruments',
#  '',
#  'significance of antiphosphatidylethanolamine antibodies in the pathogenesis of recurrent pregnancy loss',
#  '',
#  'prognostic implications of the motor symptoms of parkinsons disease with respect to clinical computertomographic and psychometric parameters',
#  '',
#  'warfarin',
#  '',
#  'role of pathology indices in the management of severe lupus glomerulonephritis lupus nephritis collaborative study group',
#  '',
#  'maturation fertilization and development of dog oocytes in vitro',
#  '',
#  'association and mediation analyses among multiple metals exposure plasma folate and communitybased impaired estimated glomerular filtration rate in central taiwan',
#  '',
#  'production and characterization of monoclonal antibodies against bacteroides forsythus and wolinella recta',
#  '',
#  'distinct sarscov2 antibody reactivity patterns elicited by natural infection and mrna vaccination',
#  '',
#  'plasma prednisolone levels in man following administration in plain and entericcoated forms',
#  '',
#  'the costeffectiveness of nurse refresher programs',
#  '',
#  'positive energy density leads to no squeezing',
#  '',
#  'large language models challenge the future of higher education',
#  '',
#  'the young wide and very low mass visual binary lori167',
#  '',
#  'integrated gas chromatographymass spectrometry and liquid chromatographyquadruple time of flightmass spectrometrybased untargeted metabolomics reveal possible metabolites related to antioxidant activity in stingless bee honey',
#  '',
#  'interfacial motion in flexo and orderelectric switching between   nematic filled states',
#  '',
#  'hemolytic diseases of the erythrocyte membrane',
#  '',
#  'investigation of the dielectric response and the transport properties of samarium and strontiumbased manganite',
#  '',
#  'flat bands in fractallike geometry',
#  '',
#  'simulations of the magnetorotational instability in corecollapse   supernovae',
#  '',
#  'analysis of outer membrane ultrastructure of pathogenic treponema and borrelia species by freezefracture electron microscopy',
#  '',
#  'dynamics of orbital boost maneuver of low earth orbit satellites by electrodynamic tethers',
#  '',
#  'diurnal and postural variations in plasma atrial natriuretic factor plasma guanosine 35cyclic monophosphate and sodium excretion',
#  '',
#  'liquid biopsy applications in the clinic',
#  '',
#  'connected health for growth hormone treatment research and clinical practice learnings from different sources of realworld evidence rwelarge electronically collected datasets surveillance studies and individual patients cases',
#  '',
#  'letter detached ciliary tufts in cervicovaginal smears',
#  '',
#  'abo determination in blood stains on stain carriers pretreated with usual household products',
#  '',
#  'phytoliths in selected broadleaved trees in china',
#  '',
#  'similar bacterial communities on healthy and injured skin of black tip reef sharks',
#  '',
#  'a complicated case of ciliary body melanoma and glaucoma',
#  '',
#  'ion movement and contractility in heart cells',
#  '',
#  'the ambivalent effects of early and late administration of mannitol in coldinduced brain oedema',
#  '',
#  'ontogeny of recognition specificity and functionality for the broadly neutralizing antihiv antibody 4e10',
#  '',
#  'convex and starshaped sets associated with stable distributions',
#  '',
#  'endometrial cancer and combined oral contraceptives the who collaborative study of neoplasia and steroid contraceptives',
#  '',
#  'the oneloop amplitudes for higgs  4 partons with full mass effects',
#  '',
#  'global bandits',
#  '',
#  'the clinical ethics consultant what role is there for religious beliefs',
#  '',
#  'challenges in perioperative animal care for orthotopic implantation of tissueengineered pulmonary valves in the ovine model',
#  '',
#  'coagulation abnormalities induced by russells viper venom in the rhesus monkey',
#  '',
#  'longitudinal analysis of the development of pulmonary function in childhood',
#  '',
#  'evaluation of the potential use of satellitederived xco2 in detecting co2\xa0enhancement in megacities with limited ground observations a case study in seoul using orbiting carbon observatory2',
#  '',
#  'dark user experience from manipulation to deception',
#  '',
#  'a simple algorithm for defining the mean cardiac cycle of aortic flow and pressure during steady state',
#  '',
#  'epilepsy by looking at patterns',
#  '',
#  'molecular dynamics of shear banding flow in associative polymers solutions effect of sticker groups location',
#  '',
#  'correction to discrete hamiltonian variational mechanics and hamels integrators',
#  '',
#  'time asymmetric extensions of general relativity',
#  '',
#  'molecular basis of the antihyperglycemic activity of ra3 in hyperlipidemic and streptozotocininduced type 2 diabetes in rats',
#  '',
#  'mrivisible perivascular space pvs changes with longduration spaceflight',
#  '',
#  'the elementary courses in psychology',
#  '',
#  'some discussable solutions for prosthetic classes in a teaching scheme',
#  '',
#  'disability in combined wrist trauma',
#  '',
#  'zur haftung einer heilpraktikerin fr fehlerhafte therapeutische aufklrung im bergang von begleitender zu rein alternativmedizinischer behandlung',
#  '',
#  'the value of taylors technique in the management of perforated gastroduodenal ulcer with 71 case reports authors transl',
#  '',
#  'neurofilament phosphorylation in cultured bovine adrenal chromaffin cells is stimulated by phorbol ester',
#  '',
#  'oral administration of live or heatkilled',
#  '',
#  'phientropy inequality and invariant probability measure for sdes   with jump',
#  '',
#  'should acute diarrhea be treated with carbon kaolinpectin diphenoxylateor with nothing at all',
#  '',
#  'specific contribution of dietary polyunsaturated fatty acids of the n3 series to the development of nervous system membranes',
#  '',
#  'evaluation of operation state for operators in npp main control room using human behavior recognition',
#  '',
#  'general relativistic decoherence with applications to dark matter   detection',
#  '',
#  'automated big traffic analytics for cyber security',
#  '',
#  'textures and semilocal strings in susy hybrid inflation',
#  '',
#  'prediction of lameness using automatically recorded activity behavior and production data in postparturient irish dairy cows',
#  '',
#  'stability of ferromagnetism in hubbard models with degenerate   singleparticle ground states',
#  '',
#  'artificial intelligence combination processing for multilayer networks',
#  '',
#  'fundamental planes and the barless msigma relation for supermassive   black holes',
#  '',
#  'quantitative electrophysiological assessments as predictive markers of lower limb motor recovery after spinal cord injury a pilot study with an adaptive trial design',
#  '',
#  'continuous low flow ascites drainage through the urinary bladder via the alfapump system in palliative patients with malignant ascites',
#  '',
#  'noncrossed products in witts theorem',
#  '',
#  'dilation of esophageal strictures a new technique controlled by fiberoptic endoscopy',
#  '',
#  'probabilistic degenerate fubini polynomials associated with random   variables',
#  '',
#  'the personality of bipolar manicdepressive patients',
#  '',
#  'spontaneous injury in isolated sheep lungs role of perfusate leukocytes and platelets',
#  '',
#  'squarefree values of multivariate polynomials over function fields in   linear sparse sets',
#  '',
#  'relic neutrino freezeout dependence on natural constants',
#  '',
#  'a mathematical analysis and evaluation of varroa mite control methods   for a miteinfested honey bee colony',
#  '',
#  'distribution of mammalianlike melanopsin in cyclostome retinas exhibiting a different extent of visual functions',
#  '',
#  'gallstone ileus report of 23 cases with emphasis on factors affecting survival',
#  '',
#  'mucoepidermoid tumors of the lung',
#  '',
#  'in vivo effects of hyperdiploid ly1 b cells of nzb origin',
#  '',
#  'inactivation of sarscov2 on surfaces and in solution with virusend tx10 a novel disinfectant',
#  '',
#  'annexin a2stat3oncostatin m receptor axis drives phenotypic and mesenchymal changes in glioblastoma',
#  '',
#  'how thorough clinical observational studies on rheumatoid arthritis can have an impact on the field',
#  '',
#  'treatment of refractory lymphoma with high dose cytarabine cyclophosphamide and either tbi or vp16 followed by autologous bone marrow transplantation',
#  '',
#  'correction high',
#  '',
#  'cassandra still a myth',
#  '',
#  'a design strategy for 2d multiferroics',
#  '',
#  'multidimensional separation prior to mass spectrometry getting closer   to the bottom of the iceberg',
#  '',
#  'intravenous ferric derisomaltose for irondeficiency anemia associated with gastrointestinal diseases a singlearm randomized uncontrolled openlabel study',
#  '',
#  'pseudogorenstein and level hibi rings',
#  '',
#  'controlling anammox speciation and biofilm attachment strategy using nbiotransformation intermediates and organic carbon levels',
#  '',
#  'the gaiaeso survey age spread in the star forming region ngc6530 from   the hr diagram and gravity indicators',
#  '',
#  'polyclonal lymphoma confined to renal allograft case report',
#  '',
#  'subactue thyroiditis and recurrent acute pericarditis report of a case',
#  '',
#  'mycoplasma infection in children',
#  '',
#  'the paradox of closing mutual funds to new investors',
#  '',
#  'the role of the endocrine thymus in female reproduction',
#  '',
#  'confining bethesalpeter equation from scalar qcd',
#  '',
#  'one way to verify the molecular picture of exotic hadrons from dk to   ddkdbardk',
#  '',
#  'oralmotor dysfunction and feeding disorders of infants with turner syndrome',
#  '',
#  'computerbased cognitive interventions for mild cognitive impairment and dementia in older adults protocol for a systematic review of published studies and metaanalysis',
#  '',
#  'humoral and cellular immune responses to the mrna1273 sarscov2 vaccine booster in patients on maintenance dialysis',
#  '',
#  'ionized gas in damped lyman alpha protogalaxies ii comparison between   models and the kinematic data',
#  '',
#  'stable source reconstruction from a finite number of measurements in the   multifrequency inverse source problem',
#  '',
#  'optimal local implementation of nonlocal quantum gates',
#  '',
#  'topographic organization in the corticocortical connections of medial agranular cortex in rats',
#  '',
#  'coloroctet scalars in dirac gaugino models with broken r symmetry',
#  '',
#  'an integralfield spectroscopic strong lens survey',
#  '',
#  'test of special relativity and equivalence principle from neutrinoless   double beta decay',
#  '',
#  'livin promotes th2type immune response in airway allergic diseases',
#  '',
#  'nonparathormoneinduced hypercalcemia with transitional cell carcinoma',
#  '',
#  'teleparallel energymomentum distribution of lewispapapetrou spacetimes',
#  '',
#  'look before you leap tumor of the thoracic wall',
#  '',
#  'model experiments for the analysis of the determining factors of the dissolution rate of pvc polyvinyl chloride base frames',
#  '',
#  'review of noblegas spin amplification via the spinexchange collisions',
#  '',
#  'toward a just society lessons from observations on the primary prevention of psychopathology',
#  '',
#  'agriculture in urban planning generating livelihoods and food security',
#  '',
#  'a phase 1 randomized open label rectal safety acceptability pharmacokinetic and pharmacodynamic study of three formulations of tenofovir 1 gel the charm01 study',
#  '',
#  'apomyoglobin forms a micellar complex with phospholipid at low ph',
#  '',
#  'integral equation models for solvent in macromolecular crystals',
#  '',
#  'advancing precision public health for obesity in children',
#  '',
#  'broadband polarization insensitivity and high detection efficiency in   highfillfactor superconducting microwire singlephoton detectors',
#  '',
#  'psychology for students of education',
#  '',
#  'topological summation of observables measured with dynamical overlap   fermions',
#  '',
#  'the bakerrichter spectrum as cobordism of quasitoric manifolds',
#  '',
#  'screening of noiseinduced hearing loss nihlassociated snps and the assessment of its genetic susceptibility',
#  '',
#  'lowrisk trials for children and pregnant women threatened by unnecessary strict regulations does the coming eu clinical trial regulation offer a solution',
#  '',
#  'cloning of the gene for ribosomal protein hs4 in the archaebacterium halobacterium halobium',
#  '',
#  'magnetic resonance imaging in congenital dislocation of the hip',
#  '',
#  'cvarbased safety analysis in the infinite time horizon setting',
#  '',
#  'alphanoradrenergic receptor binding in mammalian brain differential labeling of agonist and antagonist states',
#  '',
#  'calibration mixture for estimation of peptide molecular weight by exclusion chromatography',
#  '',
#  'no title found',
#  '',
#  'long term virucidal activity of rosin soap on surfaces',
#  '',
#  'crosslinking of surface antigens causes mobilization of intracellular ionized calcium in t lymphocytes',
#  '',
#  'primary lung abscess a retrospective study of 49 cases',
#  '',
#  'highdensity stacked microcoils integrated microminiaturized electromagnetic vibration energy harvester for selfpowered acceleration sensing',
#  '',
#  'accessing continuousvariable entanglement witnesses with multimode spin   observables',
#  '',
#  'nutritional cu fe interrelation affected by energy levels the effect of iron and thyroxine on pigs given extra copper',
#  '',
#  'temporal dynamics of implicit memory underlying serial dependence',
#  '',
#  'vascular approach in patients on periodic hemodialysis',
#  '',
#  'prophylactic adjunctive use of antilymphocyte globulin in cadaveric renal transplantation',
#  '',
#  'out of africa the cakewalk in twentiethcentury french concert music',
#  '',
#  'autocatalytic microtubule nucleation determines the size and mass of spindles',
#  '',
#  'global constraints within the developmental program of the drosophila wing',
#  '',
#  'some reflections on smithsonian economics',
#  '',
#  'the effect of a gas atmosphere on the formation of colloidal platinum nanoparticles in liquid phase synthesis',
#  '',
#  'propylthiouracilinduced fatal hepatic necrosis',
#  '',
#  'electronic structure modification of sinanocrystals with f4 tcnq',
#  '',
#  'socalled lymphoepithelioma',
#  '',
#  'the impact of pharmacotherapy on the treatment of mental illness',
#  '',
#  'the mechanosensitive piezo1 orchestrating angiogenesis is essential in bone fracture repair',
#  '',
#  'communication public opinion and democracy new challenges',
#  '',
#  'perspectives of the control of opisthorchis invasion by the method of treating the molluskan population',
#  '',
#  'the nominal range of rocky planet masses radii surface gravities and   bulk densities',
#  '',
#  'adenosine a2a receptors control synaptic remodeling in the adult brain',
#  '',
#  'space group symmetry of bafe2se3 ab initioexperiment phonon   study',
#  '',
#  'characterization of the pol3 gene product from schizosaccharomyces pombe indicates interspecies conservation of the catalytic subunit of dna polymerase delta',
#  '',
#  'hypocomplementemia in procainamideassociated systemic lupus erythematosus',
#  '',
#  'no title found',
#  '',
#  'gravitational instability of einsteingaussbonnet black holes under   tensor mode perturbations',
#  '',
#  'acquired alterations of hypothalamic gene expression of insulin and leptin receptors and glucose transporters in prenatally highglucose exposed threeweek old chickens do not coincide with aberrant promoter dna methylation',
#  '',
#  'de stem van pleegkinderen',
#  '',
#  'building a corpus of legal argumentation in japanese judgement documents towards structurebased summarisation',
#  '',
#  'tabacco tomorrow a familial habit',
#  '',
#  'iron functionalized silica particles as an ingenious sorbent for removal of fluoride from water',
#  '',
#  'an equilibrium theory of economics',
#  '',
#  'women in medicine patient care issues 1',
#  '',
#  'radioactivity no ground for panic in the treatment of radioactive injuries',
#  '',
#  'devanagari ancient documents recognition using statistical feature extraction techniques',
#  '',
#  'filled julia sets of chebyshev polynomials',
#  '',
#  'revisiting mutagenesis at nonb dna motifs in the human genome',
#  '',
#  'the influence of 2 topical digestive agents on the pharmacokinetics of acetylsalicylic acid',
#  '',
#  'selfsupervised learning for segmentation and quantification of dopamine   neurons in parkinsons disease',
#  '',
#  'the varied appearances of starch particles in smears and paraffin sections',
#  '',
#  'influence of the surface band structure on electron emission spectra   from metal surfaces',
#  '',
#  'dual sensitivity of spiropyranfunctionalized carbon dots for full color conversions',
#  '',
#  'modified technique for smallincision lenticule extraction yes swing technique',
#  '',
#  'hla 1992 perspectives in bone marrow transplantation',
#  '',
#  'shigellosis induced acute watery diarrhoea at delhi',
#  '',
#  'a minimal set of top anomalous couplings',
#  '',
#  'bilateral renalcell carcinomas',
#  '',
#  'glutaminea nonessential but important amino acid',
#  '',
#  'chemical characterization of a new haemoglobin variant haemoglobin j cubujuqui alpha2141hc3arg replaced by ser beta2',
#  '',
#  'hyperpropulsor activator',
#  '',
#  'contents of partitions and the combinatorics of permutation   factorizations in genus 0',
#  '',
#  'nonnatural death masquerading as sids sudden infant death syndrome',
#  '',
#  'some personal recollections of coy lay',
#  '',
#  'bitgraphblas bitlevel optimizations of matrixcentric graph   processing on gpu',
#  '',
#  'efficiently predicting protein stability changes upon singlepoint   mutation with large language models',
#  '',
#  'is it necessary to control quality 2',
#  '',
#  'white matter integrity is associated with cognition and amyloid burden in older adult koreans along the alzheimers disease continuum',
#  '',
#  'history as the news camera saw it',
#  '',
#  'the real graded brauer group',
#  '',
#  'release of endogenous 5hydroxytryptamine in rat ventral hippocampus evoked by electrical stimulation of the dorsal raphe nucleus as detected by microdialysis sensitivity to tetrodotoxin calcium and calcium antagonists',
#  '',
#  'survival and adequacy in longterm hemodialysis',
#  '',
#  'persistent hemodynamic improvement with shortterm nitrate therapy in patients with chronic congestive heart failure already treated with captopril',
#  '',
#  '3d matting a soft segmentation method applied in computed tomography',
#  '',
#  'follicle development as an orchestrated signaling network in a 3d organoid',
#  '',
#  'influence of nafld and bariatric surgery on hepatic and adipose tissue mitochondrial biogenesis and respiration',
#  '',
#  'chemical and behavioural strategies along the spectrum of host specificity in antassociated silverfish',
#  '',
#  'selective transport of atomic excitations in a driven chiralcoupled   atomic chain',
#  '',
#  'characterization of human tissuetype plasminogen activator with monoclonal antibodies mapping of epitopes and binding sites for fibrin and lysine',
#  '',
#  'substrate capturing and growth in various ecosystems',
#  '',
#  'leukemia and prediccoagulation and fibrinolytic parameters in severe infection at the nadir of leukocyte after chemotherapy',
#  '',
#  'treatment of endometriosis with gonadotropin releasing hormone agonist buserelin',
#  '',
#  'descriptors of intrinsic hydrodynamic thermal transport screening a   phonon database in a machine learning approach',
#  '',
#  'ganglioside composition in common acute lymphoblastic leukaemia',
#  '',
#  'potential cardiotonic agents 4 synthesis cardiovascular activity molecular and crystal structure of 5phenyl and 44pyridinylsubstituted 21hpyridinethiones',
#  '',
#  'the vjosa river corridor a model of natural hydromorphodynamics and a hotspot of highly threatened ecosystems of european significance',
#  '',
#  'new developments in the treatment of psoriasis',
#  '',
#  'astrocyte mitochondria in whitematter injury',
#  '',
#  'graph neural networkbased android malware classification with jumping   knowledge',
#  '',
#  'four qtl clusters containing major and stable qtls for saturated fatty acid contents in a dense genetic map of cultivated peanut arachis hypogaea l',
#  '',
#  'delayed encephalopathy following cardiac arrest',
#  '',
#  'the lhcb velo upgrade',
#  '',
#  'spectral state transitions in aql x1 evidence for propeller effects',
#  '',
#  'expressing the curvature tensor and connection of a given metric in   terms of those of another metric',
#  '',
#  'a tour of deep time brings comfort in hard times',
#  '',
#  'shared spectrum access communications a neutral host micro operator   approach',
#  '',
#  'heterogeneity in thymic emigrants implications for thymectomy and immunosenescence',
#  '',
#  'actin inhibits blast transformation',
#  '',
#  'cholesterol loweringthe sense and the sensationalism',
#  '',
#  'silicon carbide grains of type c provide evidence for the production of   the unstable isotope 32si in supernovae',
#  '',
#  'rotating black hole with a probe string in horndeski gravity',
#  '',
#  'conformal field theory with two kinds of bosonic fields and two linear   dilatons',
#  '',
#  'index to volume 37',
#  '',
#  'malignant change in a solitary hamartoma of the lung a case report',
#  '',
#  'treatment of hypercalcemia associated with osseous metastases',
#  '',
#  'dense particle tracking using a learned predictive model',
#  '',
#  'predictability tests robust against parameter instability',
#  '',
#  'rhizoliths identified as prehistoric filing tools for fishhook production on san nicolas island california',
#  '',
#  'mri and ctdetermined changes of dysphagia  aspirationrelated structures dars during and after radiotherapy',
#  '',
#  'experiences with selective anatomical liver resections 8 cases of rightsided hemihepatectomy',
#  '',
#  ...]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(titles)
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for line in titles:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# 填充序列以保持统一长度
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))


# 分割为特征和标签
predictors, label = input_sequences[:,:-1], input_sequences[:,-1]
label = to_categorical(label, num_classes=total_words)

# %%
# 定义模型
def create_model(total_words, max_sequence_len):
    model = Sequential()
    model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(100))
    model.add(Dense(total_words, activation='softmax'))
    # 编译模型
    model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.01), metrics=['accuracy'])
    return model


# 创建模型
model = create_model(total_words, max_sequence_len)
model.summary()

# 设置checkpoint
checkpoint_path = 'model_checkpoint.h5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='loss', verbose=1, save_best_only=True, mode='min')

# 训练模型
model.fit(predictors, label, epochs=100, verbose=1, callbacks=[checkpoint])

# 保存tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 45, 100)           900800
#
#  lstm_10 (LSTM)              (None, 45, 150)           150600
#
#  lstm_11 (LSTM)              (None, 100)               100400
#
#  dense_5 (Dense)             (None, 9008)              909808
#
# =================================================================
# Total params: 2,061,608
# Trainable params: 2,061,608
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 786/786 [==============================] - ETA: 0s - loss: 8.9245 - accuracy: 0.0640
# Epoch 1: loss improved from inf to 8.92454, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 64ms/step - loss: 8.9245 - accuracy: 0.0640
# Epoch 2/100
# 786/786 [==============================] - ETA: 0s - loss: 7.7476 - accuracy: 0.0775
# Epoch 2: loss improved from 8.92454 to 7.74757, saving model to model_checkpoint.h5
# 786/786 [==============================] - 56s 71ms/step - loss: 7.7476 - accuracy: 0.0775
# Epoch 3/100
# 786/786 [==============================] - ETA: 0s - loss: 7.2476 - accuracy: 0.0985
# Epoch 3: loss improved from 7.74757 to 7.24761, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 7.2476 - accuracy: 0.0985
# Epoch 4/100
# 786/786 [==============================] - ETA: 0s - loss: 7.0021 - accuracy: 0.1076
# Epoch 4: loss improved from 7.24761 to 7.00213, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 7.0021 - accuracy: 0.1076
# Epoch 5/100
# 786/786 [==============================] - ETA: 0s - loss: 6.7878 - accuracy: 0.1158
# Epoch 5: loss improved from 7.00213 to 6.78779, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 6.7878 - accuracy: 0.1158
# Epoch 6/100
# 786/786 [==============================] - ETA: 0s - loss: 6.5341 - accuracy: 0.1246
# Epoch 6: loss improved from 6.78779 to 6.53407, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 6.5341 - accuracy: 0.1246
# Epoch 7/100
# 786/786 [==============================] - ETA: 0s - loss: 6.2256 - accuracy: 0.1355
# Epoch 7: loss improved from 6.53407 to 6.22562, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 66ms/step - loss: 6.2256 - accuracy: 0.1355
# Epoch 8/100
# 786/786 [==============================] - ETA: 0s - loss: 5.9013 - accuracy: 0.1454
# Epoch 8: loss improved from 6.22562 to 5.90130, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 5.9013 - accuracy: 0.1454
# Epoch 9/100
# 786/786 [==============================] - ETA: 0s - loss: 5.5429 - accuracy: 0.1567
# Epoch 9: loss improved from 5.90130 to 5.54293, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 5.5429 - accuracy: 0.1567
# Epoch 10/100
# 786/786 [==============================] - ETA: 0s - loss: 5.1700 - accuracy: 0.1680
# Epoch 10: loss improved from 5.54293 to 5.17002, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 5.1700 - accuracy: 0.1680
# Epoch 11/100
# 786/786 [==============================] - ETA: 0s - loss: 4.7952 - accuracy: 0.1814
# Epoch 11: loss improved from 5.17002 to 4.79516, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 4.7952 - accuracy: 0.1814
# Epoch 12/100
# 786/786 [==============================] - ETA: 0s - loss: 4.4480 - accuracy: 0.2022
# Epoch 12: loss improved from 4.79516 to 4.44798, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 4.4480 - accuracy: 0.2022
# Epoch 13/100
# 786/786 [==============================] - ETA: 0s - loss: 4.0869 - accuracy: 0.2269
# Epoch 13: loss improved from 4.44798 to 4.08688, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 4.0869 - accuracy: 0.2269
# Epoch 14/100
# 786/786 [==============================] - ETA: 0s - loss: 3.7359 - accuracy: 0.2632
# Epoch 14: loss improved from 4.08688 to 3.73586, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 3.7359 - accuracy: 0.2632
# Epoch 15/100
# 786/786 [==============================] - ETA: 0s - loss: 3.4124 - accuracy: 0.3027
# Epoch 15: loss improved from 3.73586 to 3.41236, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 3.4124 - accuracy: 0.3027
# Epoch 16/100
# 786/786 [==============================] - ETA: 0s - loss: 3.1378 - accuracy: 0.3412
# Epoch 16: loss improved from 3.41236 to 3.13780, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 3.1378 - accuracy: 0.3412
# Epoch 17/100
# 786/786 [==============================] - ETA: 0s - loss: 2.8815 - accuracy: 0.3802
# Epoch 17: loss improved from 3.13780 to 2.88145, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 2.8815 - accuracy: 0.3802
# Epoch 18/100
# 786/786 [==============================] - ETA: 0s - loss: 2.6742 - accuracy: 0.4105
# Epoch 18: loss improved from 2.88145 to 2.67425, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 2.6742 - accuracy: 0.4105
# Epoch 19/100
# 786/786 [==============================] - ETA: 0s - loss: 2.5035 - accuracy: 0.4415
# Epoch 19: loss improved from 2.67425 to 2.50354, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 2.5035 - accuracy: 0.4415
# Epoch 20/100
# 786/786 [==============================] - ETA: 0s - loss: 2.3263 - accuracy: 0.4699
# Epoch 20: loss improved from 2.50354 to 2.32634, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 2.3263 - accuracy: 0.4699
# Epoch 21/100
# 786/786 [==============================] - ETA: 0s - loss: 2.1811 - accuracy: 0.4969
# Epoch 21: loss improved from 2.32634 to 2.18106, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 2.1811 - accuracy: 0.4969
# Epoch 22/100
# 786/786 [==============================] - ETA: 0s - loss: 2.0484 - accuracy: 0.5192
# Epoch 22: loss improved from 2.18106 to 2.04842, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 2.0484 - accuracy: 0.5192
# Epoch 23/100
# 786/786 [==============================] - ETA: 0s - loss: 1.9518 - accuracy: 0.5373
# Epoch 23: loss improved from 2.04842 to 1.95176, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.9518 - accuracy: 0.5373
# Epoch 24/100
# 786/786 [==============================] - ETA: 0s - loss: 1.8206 - accuracy: 0.5626
# Epoch 24: loss improved from 1.95176 to 1.82064, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 1.8206 - accuracy: 0.5626
# Epoch 25/100
# 786/786 [==============================] - ETA: 0s - loss: 1.7358 - accuracy: 0.5785
# Epoch 25: loss improved from 1.82064 to 1.73577, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 67ms/step - loss: 1.7358 - accuracy: 0.5785
# Epoch 26/100
# 786/786 [==============================] - ETA: 0s - loss: 1.6569 - accuracy: 0.5962
# Epoch 26: loss improved from 1.73577 to 1.65692, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.6569 - accuracy: 0.5962
# Epoch 27/100
# 786/786 [==============================] - ETA: 0s - loss: 1.5880 - accuracy: 0.6084
# Epoch 27: loss improved from 1.65692 to 1.58796, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 66ms/step - loss: 1.5880 - accuracy: 0.6084
# Epoch 28/100
# 786/786 [==============================] - ETA: 0s - loss: 1.5219 - accuracy: 0.6196
# Epoch 28: loss improved from 1.58796 to 1.52191, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 1.5219 - accuracy: 0.6196
# Epoch 29/100
# 786/786 [==============================] - ETA: 0s - loss: 1.4699 - accuracy: 0.6270
# Epoch 29: loss improved from 1.52191 to 1.46992, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.4699 - accuracy: 0.6270
# Epoch 30/100
# 786/786 [==============================] - ETA: 0s - loss: 1.4526 - accuracy: 0.6322
# Epoch 30: loss improved from 1.46992 to 1.45258, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.4526 - accuracy: 0.6322
# Epoch 31/100
# 786/786 [==============================] - ETA: 0s - loss: 1.4118 - accuracy: 0.6414
# Epoch 31: loss improved from 1.45258 to 1.41180, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 67ms/step - loss: 1.4118 - accuracy: 0.6414
# Epoch 32/100
# 786/786 [==============================] - ETA: 0s - loss: 1.3393 - accuracy: 0.6575
# Epoch 32: loss improved from 1.41180 to 1.33930, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 1.3393 - accuracy: 0.6575
# Epoch 33/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2880 - accuracy: 0.6683
# Epoch 33: loss improved from 1.33930 to 1.28797, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 1.2880 - accuracy: 0.6683
# Epoch 34/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2667 - accuracy: 0.6680
# Epoch 34: loss improved from 1.28797 to 1.26665, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.2667 - accuracy: 0.6680
# Epoch 35/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2531 - accuracy: 0.6720
# Epoch 35: loss improved from 1.26665 to 1.25315, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 66ms/step - loss: 1.2531 - accuracy: 0.6720
# Epoch 36/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2398 - accuracy: 0.6725
# Epoch 36: loss improved from 1.25315 to 1.23982, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 1.2398 - accuracy: 0.6725
# Epoch 37/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2230 - accuracy: 0.6788
# Epoch 37: loss improved from 1.23982 to 1.22298, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 1.2230 - accuracy: 0.6788
# Epoch 38/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1940 - accuracy: 0.6875
# Epoch 38: loss improved from 1.22298 to 1.19397, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 1.1940 - accuracy: 0.6875
# Epoch 39/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1719 - accuracy: 0.6894
# Epoch 39: loss improved from 1.19397 to 1.17187, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 1.1719 - accuracy: 0.6894
# Epoch 40/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1539 - accuracy: 0.6969
# Epoch 40: loss improved from 1.17187 to 1.15389, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1539 - accuracy: 0.6969
# Epoch 41/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1727 - accuracy: 0.6905
# Epoch 41: loss did not improve from 1.15389
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1727 - accuracy: 0.6905
# Epoch 42/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1471 - accuracy: 0.6934
# Epoch 42: loss improved from 1.15389 to 1.14714, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 66ms/step - loss: 1.1471 - accuracy: 0.6934
# Epoch 43/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1485 - accuracy: 0.6920
# Epoch 43: loss did not improve from 1.14714
# 786/786 [==============================] - 53s 68ms/step - loss: 1.1485 - accuracy: 0.6920
# Epoch 44/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1262 - accuracy: 0.6998
# Epoch 44: loss improved from 1.14714 to 1.12621, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 68ms/step - loss: 1.1262 - accuracy: 0.6998
# Epoch 45/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0784 - accuracy: 0.7107
# Epoch 45: loss improved from 1.12621 to 1.07839, saving model to model_checkpoint.h5
# 786/786 [==============================] - 54s 69ms/step - loss: 1.0784 - accuracy: 0.7107
# Epoch 46/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0981 - accuracy: 0.7067
# Epoch 46: loss did not improve from 1.07839
# 786/786 [==============================] - 54s 69ms/step - loss: 1.0981 - accuracy: 0.7067
# Epoch 47/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0482 - accuracy: 0.7139
# Epoch 47: loss improved from 1.07839 to 1.04822, saving model to model_checkpoint.h5
# 786/786 [==============================] - 63s 81ms/step - loss: 1.0482 - accuracy: 0.7139
# Epoch 48/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0416 - accuracy: 0.7180
# Epoch 48: loss improved from 1.04822 to 1.04157, saving model to model_checkpoint.h5
# 786/786 [==============================] - 67s 85ms/step - loss: 1.0416 - accuracy: 0.7180
# Epoch 49/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.7196
# Epoch 49: loss improved from 1.04157 to 1.02764, saving model to model_checkpoint.h5
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0276 - accuracy: 0.7196
# Epoch 50/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0534 - accuracy: 0.7113
# Epoch 50: loss did not improve from 1.02764
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0534 - accuracy: 0.7113
# Epoch 51/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0444 - accuracy: 0.7156
# Epoch 51: loss did not improve from 1.02764
# 786/786 [==============================] - 52s 67ms/step - loss: 1.0444 - accuracy: 0.7156
# Epoch 52/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0311 - accuracy: 0.7190
# Epoch 52: loss did not improve from 1.02764
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0311 - accuracy: 0.7190
# Epoch 53/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9940 - accuracy: 0.7295
# Epoch 53: loss improved from 1.02764 to 0.99404, saving model to model_checkpoint.h5
# 786/786 [==============================] - 51s 65ms/step - loss: 0.9940 - accuracy: 0.7295
# Epoch 54/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9968 - accuracy: 0.7232
# Epoch 54: loss did not improve from 0.99404
# 786/786 [==============================] - 53s 67ms/step - loss: 0.9968 - accuracy: 0.7232
# Epoch 55/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0108 - accuracy: 0.7243
# Epoch 55: loss did not improve from 0.99404
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0108 - accuracy: 0.7243
# Epoch 56/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0358 - accuracy: 0.7173
# Epoch 56: loss did not improve from 0.99404
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0358 - accuracy: 0.7173
# Epoch 57/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9791 - accuracy: 0.7293
# Epoch 57: loss improved from 0.99404 to 0.97906, saving model to model_checkpoint.h5
# 786/786 [==============================] - 56s 71ms/step - loss: 0.9791 - accuracy: 0.7293
# Epoch 58/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9461 - accuracy: 0.7396
# Epoch 58: loss improved from 0.97906 to 0.94610, saving model to model_checkpoint.h5
# 786/786 [==============================] - 52s 66ms/step - loss: 0.9461 - accuracy: 0.7396
# Epoch 59/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9752 - accuracy: 0.7324
# Epoch 59: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 67ms/step - loss: 0.9752 - accuracy: 0.7324
# Epoch 60/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.7295
# Epoch 60: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 0.9900 - accuracy: 0.7295
# Epoch 61/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9961 - accuracy: 0.7263
# Epoch 61: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 0.9961 - accuracy: 0.7263
# Epoch 62/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0424 - accuracy: 0.7144
# Epoch 62: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0424 - accuracy: 0.7144
# Epoch 63/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0557 - accuracy: 0.7124
# Epoch 63: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0557 - accuracy: 0.7124
# Epoch 64/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0113 - accuracy: 0.7253
# Epoch 64: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0113 - accuracy: 0.7253
# Epoch 65/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0074 - accuracy: 0.7260
# Epoch 65: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0074 - accuracy: 0.7260
# Epoch 66/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9968 - accuracy: 0.7264
# Epoch 66: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 0.9968 - accuracy: 0.7264
# Epoch 67/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0652 - accuracy: 0.7136
# Epoch 67: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0652 - accuracy: 0.7136
# Epoch 68/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0467 - accuracy: 0.7159
# Epoch 68: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 70ms/step - loss: 1.0467 - accuracy: 0.7159
# Epoch 69/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0086 - accuracy: 0.7220
# Epoch 69: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0086 - accuracy: 0.7220
# Epoch 70/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9991 - accuracy: 0.7253
# Epoch 70: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 70ms/step - loss: 0.9991 - accuracy: 0.7253
# Epoch 71/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9993 - accuracy: 0.7255
# Epoch 71: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 0.9993 - accuracy: 0.7255
# Epoch 72/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1070 - accuracy: 0.7133
# Epoch 72: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1070 - accuracy: 0.7133
# Epoch 73/100
# 786/786 [==============================] - ETA: 0s - loss: 1.5593 - accuracy: 0.6201
# Epoch 73: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.5593 - accuracy: 0.6201
# Epoch 74/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2821 - accuracy: 0.6668
# Epoch 74: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 69ms/step - loss: 1.2821 - accuracy: 0.6668
# Epoch 75/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1056 - accuracy: 0.7051
# Epoch 75: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1056 - accuracy: 0.7051
# Epoch 76/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0172 - accuracy: 0.7225
# Epoch 76: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0172 - accuracy: 0.7225
# Epoch 77/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9899 - accuracy: 0.7285
# Epoch 77: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 70ms/step - loss: 0.9899 - accuracy: 0.7285
# Epoch 78/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0150 - accuracy: 0.7217
# Epoch 78: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0150 - accuracy: 0.7217
# Epoch 79/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1073 - accuracy: 0.7014
# Epoch 79: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1073 - accuracy: 0.7014
# Epoch 80/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1475 - accuracy: 0.6940
# Epoch 80: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 67ms/step - loss: 1.1475 - accuracy: 0.6940
# Epoch 81/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0587 - accuracy: 0.7124
# Epoch 81: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 69ms/step - loss: 1.0587 - accuracy: 0.7124
# Epoch 82/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0254 - accuracy: 0.7205
# Epoch 82: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0254 - accuracy: 0.7205
# Epoch 83/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0343 - accuracy: 0.7160
# Epoch 83: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 69ms/step - loss: 1.0343 - accuracy: 0.7160
# Epoch 84/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0710 - accuracy: 0.7108
# Epoch 84: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0710 - accuracy: 0.7108
# Epoch 85/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1133 - accuracy: 0.7040
# Epoch 85: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.1133 - accuracy: 0.7040
# Epoch 86/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0868 - accuracy: 0.7083
# Epoch 86: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0868 - accuracy: 0.7083
# Epoch 87/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0628 - accuracy: 0.7145
# Epoch 87: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0628 - accuracy: 0.7145
# Epoch 88/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0214 - accuracy: 0.7243
# Epoch 88: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 70ms/step - loss: 1.0214 - accuracy: 0.7243
# Epoch 89/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1981 - accuracy: 0.6929
# Epoch 89: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 69ms/step - loss: 1.1981 - accuracy: 0.6929
# Epoch 90/100
# 786/786 [==============================] - ETA: 0s - loss: 1.2049 - accuracy: 0.6869
# Epoch 90: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.2049 - accuracy: 0.6869
# Epoch 91/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0773 - accuracy: 0.7119
# Epoch 91: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0773 - accuracy: 0.7119
# Epoch 92/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0481 - accuracy: 0.7178
# Epoch 92: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 69ms/step - loss: 1.0481 - accuracy: 0.7178
# Epoch 93/100
# 786/786 [==============================] - ETA: 0s - loss: 0.9948 - accuracy: 0.7282
# Epoch 93: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 0.9948 - accuracy: 0.7282
# Epoch 94/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0282 - accuracy: 0.7198
# Epoch 94: loss did not improve from 0.94610
# 786/786 [==============================] - 55s 69ms/step - loss: 1.0282 - accuracy: 0.7198
# Epoch 95/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0755 - accuracy: 0.7108
# Epoch 95: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 68ms/step - loss: 1.0755 - accuracy: 0.7108
# Epoch 96/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0881 - accuracy: 0.7102
# Epoch 96: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 68ms/step - loss: 1.0881 - accuracy: 0.7102
# Epoch 97/100
# 786/786 [==============================] - ETA: 0s - loss: 1.1146 - accuracy: 0.7038
# Epoch 97: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 67ms/step - loss: 1.1146 - accuracy: 0.7038
# Epoch 98/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0509 - accuracy: 0.7176
# Epoch 98: loss did not improve from 0.94610
# 786/786 [==============================] - 53s 67ms/step - loss: 1.0509 - accuracy: 0.7176
# Epoch 99/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0169 - accuracy: 0.7231
# Epoch 99: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 69ms/step - loss: 1.0169 - accuracy: 0.7231
# Epoch 100/100
# 786/786 [==============================] - ETA: 0s - loss: 1.0452 - accuracy: 0.7201
# Epoch 100: loss did not improve from 0.94610
# 786/786 [==============================] - 54s 69ms/step - loss: 1.0452 - accuracy: 0.7201

# %%
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(titles)
# total_words = len(tokenizer.word_index) + 1

# input_sequences = []
# for line in titles:
#     token_list = tokenizer.texts_to_sequences([line])[0]
#     for i in range(1, len(token_list)):
#         n_gram_sequence = token_list[:i+1]
#         input_sequences.append(n_gram_sequence)

# # 填充序列以保持统一长度
# max_sequence_len = max([len(x) for x in input_sequences])
# input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# # 分割为特征和标签
# predictors, label = input_sequences[:,:-1], input_sequences[:,-1]
# label = to_categorical(label, num_classes=total_words)

# # 定义模型
# def create_model(total_words, max_sequence_len):
#     model = Sequential()
#     model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
#     model.add(LSTM(150, return_sequences=True))
#     model.add(LSTM(100))
#     model.add(Dense(total_words, activation='softmax'))
#     # 编译模型
#     model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.01), metrics=['accuracy'])
#     return model

# # 创建模型
# model = create_model(total_words, max_sequence_len)
# model.summary()

# # 设置checkpoint
# checkpoint_path = 'model_checkpoint2.h5'
# checkpoint = ModelCheckpoint(checkpoint_path, monitor='loss', verbose=1, save_best_only=True, mode='min')

# # 训练模型
# model.fit(predictors, label, epochs=100, verbose=1, callbacks=[checkpoint])

# dump(tokenizer, open('tokenizer2.pkl', 'wb'))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 45, 100)           900800
#
#  lstm_6 (LSTM)               (None, 45, 150)           150600
#
#  lstm_7 (LSTM)               (None, 100)               100400
#
#  dense_3 (Dense)             (None, 9008)              909808
#
# =================================================================
# Total params: 2,061,608
# Trainable params: 2,061,608
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23556\4079963176.py in <module>
#      38
#      39 # 训练模型
# ---> 40 model.fit(predictors, label, epochs=100, verbose=1, callbacks=[checkpoint])
#      41
#      42 dump(tokenizer, open('tokenizer2.pkl', 'wb'))
#
# D:\Toobox\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Toobox\Anaconda\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     978         # Lifting succeeded, so variables are initialized and we can run the
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#     982       _, _, filtered_flat_args = (
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# D:\Toobox\Anaconda\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
# 测试模型：
# 加载模型
model = load_model('model_checkpoint.h5')

# 加载tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))

# %%
def generate_text(seed_text, next_words, model, tokenizer, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predictions = model.predict(token_list, verbose=0)
        predicted = np.argmax(predictions, axis=-1)[0]
        
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %%
seed_text = "Deep learning"
next_words = 10  # 生成标题的长度

generated_title = generate_text(seed_text, next_words, model, tokenizer, max_sequence_len)
print(generated_title)
# Out:
# Deep learning and tullyfisher he fingerlings surface affected by sperms school therapy

# %%
seed_text = "Deep learning"
next_words = 5  # 生成标题的长度

generated_title = generate_text(seed_text, next_words, model, tokenizer, max_sequence_len)
print(generated_title)
# Out:
# Deep learning or refreshment l koch 18881976
